# %%
# !pip install SoccerNet --upgrade

import SoccerNet
from SoccerNet.Downloader import SoccerNetDownloader
mySoccerNetDownloader=SoccerNetDownloader(LocalDirectory="path/to/SoccerNet")
# Out:
# Collecting SoccerNet
#   Downloading SoccerNet-0.1.62-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (4.67.1)
# Collecting scikit-video (from SoccerNet)
#   Downloading scikit_video-1.1.11-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (3.10.0)
# Collecting google-measurement-protocol (from SoccerNet)
#   Downloading google_measurement_protocol-1.1.0-py2.py3-none-any.whl.metadata (845 bytes)
# Collecting pycocoevalcap (from SoccerNet)
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (0.34.4)
# Collecting boto3 (from SoccerNet)
#   Downloading boto3-1.40.18-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.41.0,>=1.40.18 (from boto3->SoccerNet)
#   Downloading botocore-1.40.18-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->SoccerNet)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->SoccerNet)
#   Downloading s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: requests<3.0a0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-measurement-protocol->SoccerNet) (2.32.4)
# Collecting prices>=1.0.0 (from google-measurement-protocol->SoccerNet)
#   Downloading prices-1.1.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (1.1.8)
# Collecting InquirerPy==0.3.4 (from huggingface_hub[cli]->SoccerNet)
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (3.0.51)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (2.9.0.post0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from pycocoevalcap->SoccerNet) (2.0.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scikit-video->SoccerNet) (1.16.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.18->boto3->SoccerNet) (2.5.0)
# Requirement already satisfied: babel>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from prices>=1.0.0->google-measurement-protocol->SoccerNet) (2.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->SoccerNet) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (2025.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (0.2.13)
# Downloading SoccerNet-0.1.62-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 4.0 MB/s eta 0:00:00
# Downloading boto3-1.40.18-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 11.3 MB/s eta 0:00:00
# Downloading google_measurement_protocol-1.1.0-py2.py3-none-any.whl (5.9 kB)
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.5 MB/s eta 0:00:00
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 10.6 MB/s eta 0:00:00
# Downloading scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 41.2 MB/s eta 0:00:00
# Downloading botocore-1.40.18-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 42.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading prices-1.1.1-py3-none-any.whl (9.5 kB)
# Downloading s3transfer-0.13.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.4 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Installing collected packages: prices, pfzy, jmespath, scikit-video, pycocoevalcap, InquirerPy, google-measurement-protocol, botocore, s3transfer, boto3, SoccerNet
# Successfully installed InquirerPy-0.3.4 SoccerNet-0.1.62 boto3-1.40.18 botocore-1.40.18 google-measurement-protocol-1.1.0 jmespath-1.0.1 pfzy-0.3.4 prices-1.1.1 pycocoevalcap-1.2 s3transfer-0.13.1 scikit-video-1.1.11

# %%
! pip install SoccerNet --upgrade
import SoccerNet
from SoccerNet.Downloader import SoccerNetDownloader

mySoccerNetDownloader=SoccerNetDownloader(LocalDirectory="path/to/SoccerNet")
mySoccerNetDownloader.downloadDataTask(task="spotting-ball-2023", split=["train", "valid", "test", "challenge"], password="s0cc3rn3t")
# Out:
# Requirement already satisfied: SoccerNet in /usr/local/lib/python3.12/dist-packages (0.1.62)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (4.67.1)
# Requirement already satisfied: scikit-video in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (1.1.11)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (3.10.0)
# Requirement already satisfied: google-measurement-protocol in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (1.1.0)
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (1.2)
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (0.34.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (from SoccerNet) (1.40.18)
# Requirement already satisfied: botocore<1.41.0,>=1.40.18 in /usr/local/lib/python3.12/dist-packages (from boto3->SoccerNet) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3->SoccerNet) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from boto3->SoccerNet) (0.13.1)
# Requirement already satisfied: requests<3.0a0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-measurement-protocol->SoccerNet) (2.32.4)
# Requirement already satisfied: prices>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-measurement-protocol->SoccerNet) (1.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (1.1.8)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]->SoccerNet) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (3.0.51)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->SoccerNet) (2.9.0.post0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from pycocoevalcap->SoccerNet) (2.0.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scikit-video->SoccerNet) (1.16.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.18->boto3->SoccerNet) (2.5.0)
# Requirement already satisfied: babel>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from prices>=1.0.0->google-measurement-protocol->SoccerNet) (2.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->SoccerNet) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (2025.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (0.2.13)
# Downloading path/to/SoccerNet/spotting-ball-2023/train.zip...: : 3.94GiB [03:22, 19.5MiB/s]
# Downloading path/to/SoccerNet/spotting-ball-2023/valid.zip...: : 942MiB [02:23, 6.58MiB/s]
# Downloading path/to/SoccerNet/spotting-ball-2023/test.zip...: : 2.16GiB [01:44, 20.6MiB/s]
# Downloading path/to/SoccerNet/spotting-ball-2023/challenge.zip...: : 1.92GiB [01:36, 19.8MiB/s]

# %%
# !unzip -P s0ccc3rn3t path/to/SoccerNet/spotting-ball-2023/train.zip -d path/to/SoccerNet/spotting-ball-2023/train
# Out:
# Archive:  path/to/SoccerNet/spotting-ball-2023/train.zip
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/2_224p.mkv
#  extracting: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Blackburn Rovers - Nottingham Forest/Labels-ball.json
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Brentford - Bristol City/Labels-ball.json
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Hull City - Sheffield Wednesday/Labels-ball.json
#    creating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/train/england_efl/2019-2020/2019-10-01 - Leeds United - West Bromwich/Labels-ball.json

# %%
# !unzip -P s0ccc3rn3t path/to/SoccerNet/spotting-ball-2023/test.zip -d path/to/SoccerNet/spotting-ball-2023/test
# Out:
# Archive:  path/to/SoccerNet/spotting-ball-2023/test.zip
#    creating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/
#    creating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/
#    creating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Reading - Fulham/Labels-ball.json
#    creating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/test/england_efl/2019-2020/2019-10-01 - Stoke City - Huddersfield Town/Labels-ball.json

# %%
# !unzip -P s0ccc3rn3t path/to/SoccerNet/spotting-ball-2023/valid.zip -d path/to/SoccerNet/spotting-ball-2023/valid
# Out:
# Archive:  path/to/SoccerNet/spotting-ball-2023/valid.zip
#    creating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/
#    creating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/
#    creating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/
#   inflating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/2_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/valid/england_efl/2019-2020/2019-10-01 - Middlesbrough - Preston North End/Labels-ball.json

# %%
# !unzip -P s0ccc3rn3t path/to/SoccerNet/spotting-ball-2023/challenge.zip -d path/to/SoccerNet/spotting-ball-2023/challenge
# Out:
# Archive:  path/to/SoccerNet/spotting-ball-2023/challenge.zip
#    creating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/
#    creating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/
#    creating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-01 - Wigan Athletic - Birmingham City/
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-01 - Wigan Athletic - Birmingham City/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-01 - Wigan Athletic - Birmingham City/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-01 - Wigan Athletic - Birmingham City/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-01 - Wigan Athletic - Birmingham City/2_720p.mkv
#    creating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-02 - Cardiff City - Queens Park Rangers/
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-02 - Cardiff City - Queens Park Rangers/1_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-02 - Cardiff City - Queens Park Rangers/1_720p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-02 - Cardiff City - Queens Park Rangers/2_224p.mkv
#   inflating: path/to/SoccerNet/spotting-ball-2023/challenge/england_efl/2019-2020/2019-10-02 - Cardiff City - Queens Park Rangers/2_720p.mkv

# %%
# !pip install huggingface_hub[cli]
# SN-BAS-2025
from huggingface_hub import snapshot_download
snapshot_download(repo_id="SoccerNet/SN-BAS-2025",
                  repo_type="dataset", revision="main",
                  local_dir="SoccerNet/SN-BAS-2025")
# Out:
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (1.1.7)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.51)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[cli]) (2025.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/802 [00:00<?, ?B/s]
# test.zip:   0%|          | 0.00/4.53G [00:00<?, ?B/s]
# ExtraLabelsActionSpotting500games/test_l(…):   0%|          | 0.00/4.65M [00:00<?, ?B/s]
# ExtraLabelsActionSpotting500games/train_(…):   0%|          | 0.00/13.7M [00:00<?, ?B/s]
# challenge.zip:   0%|          | 0.00/4.23G [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# train.zip:   0%|          | 0.00/8.45G [00:00<?, ?B/s]
# ExtraLabelsActionSpotting500games/valid_(…):   0%|          | 0.00/4.43M [00:00<?, ?B/s]
# valid.zip:   0%|          | 0.00/2.04G [00:00<?, ?B/s]
# '/content/SoccerNet/SN-BAS-2025'

# %%
! git clone https://github.com/SoccerNet/sn-teamspotting.git
# Out:
# Cloning into 'sn-teamspotting'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 146 (delta 61), reused 139 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 2.09 MiB | 15.17 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !pip install pyzipper
import pyzipper
with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/train.zip') as zf:
    zf.pwd = b's0cc3rn3t'
    zf.extractall('/content/SoccerNet/SN-BAS-2025/train')
with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/test.zip') as zf:
    zf.pwd = b's0cc3rn3t'
    zf.extractall('/content/SoccerNet/SN-BAS-2025/train')
with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/valid.zip') as zf:
    zf.pwd = b's0cc3rn3t'
    zf.extractall('/content/SoccerNet/SN-BAS-2025/valid')
with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/challenge.zip') as zf:
    zf.pwd = b's0cc3rn3t'
    zf.extractall('/content/SoccerNet/SN-BAS-2025/challenge')
# Out:
# Collecting pyzipper
#   Downloading pyzipper-0.3.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.12/dist-packages (from pyzipper) (3.23.0)
# Downloading pyzipper-0.3.6-py2.py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pyzipper
# Successfully installed pyzipper-0.3.6

# %%
import os
import json
from collections import Counter

# Path to the parent folder containing the 6 subfolders
data_dir = "/content/SoccerNet/SN-BAS-2025/train"

# counter for all ball actions
all_ball_actions = Counter()

# Loop through each subfolder in data_dir recursively
for root, dirs, files in os.walk(data_dir):
    # Check if the current directory contains the Labels-ball.json file
    if "Labels-ball.json" in files:
        json_file_path = os.path.join(root, "Labels-ball.json")
        if os.path.isfile(json_file_path):
            with open(json_file_path, "r") as file:
                try:
                    data = json.load(file)

                    # Assuming JSON structure: {"annotations": [{"label": "pass"}, ...]}
                    for action in data.get("annotations", []):
                        label = action.get("label")
                        if label:
                            all_ball_actions[label] += 1
                except json.JSONDecodeError:
                    print(f"Error decoding JSON in file: {json_file_path}")

# Print summary
print("Unique Ball Actions Found:", len(all_ball_actions))
print("Ball Action Distribution:")
for action, count in all_ball_actions.items():
    print(f"{action}: {count}")
# Out:
# Unique Ball Actions Found: 12
# Ball Action Distribution:
# PASS: 4400
# DRIVE: 3746
# HIGH PASS: 646
# OUT: 476
# THROW IN: 308
# HEADER: 586
# CROSS: 237
# BALL PLAYER BLOCK: 195
# SHOT: 144
# PLAYER SUCCESSFUL TACKLE: 62
# FREE KICK: 17
# GOAL: 12

# %%
import os
import json
from collections import Counter
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score

data_dir = "/content/SoccerNet/SN-BAS-2025/"

ball_actions = []

for root, dirs, files in os.walk(data_dir):
    for f in files:
        if f.endswith("Labels-ball.json"):  # <- this ensures all matching files are found
            json_file_path = os.path.join(root, f)
            with open(json_file_path, "r") as file:
                data = json.load(file)
                for action in data.get("annotations", []):
                    label = action.get("label")
                    if label:
                        ball_actions.append(label)

print("Total actions loaded:", len(ball_actions))
print("First 10 actions:", ball_actions[:10])
# Out:
# Total actions loaded: 12433
# First 10 actions: ['PASS', 'DRIVE', 'HIGH PASS', 'PASS', 'DRIVE', 'PASS', 'DRIVE', 'OUT', 'THROW IN', 'HEADER']

# %%
# Encode actions
le = LabelEncoder()
encoded_actions = le.fit_transform(ball_actions)
num_classes = len(le.classes_)
X, y = [], []

seq_length = 5
for i in range(len(encoded_actions) - seq_length):
    X.append(encoded_actions[i:i+seq_length])
    y.append(encoded_actions[i+seq_length])

X = np.array(X, dtype='int32')
y = to_categorical(y, num_classes=num_classes)

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Num classes:", num_classes)
# Out:
# X shape: (12428, 5)
# y shape: (12428, 12)
# Num classes: 12

# %%
#Define LSTM model for action regognition
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Masking
from tensorflow.keras.utils import to_categorical
import numpy as np

# Reshape X to be 3D for LSTM (batch_size, timesteps, feature_dim)
# Since each encoded action is a single feature, feature_dim is 1
X = np.expand_dims(X, axis=-1)

timesteps = X.shape[1]
feature_dim = X.shape[2]


model = Sequential([
    LSTM(128, return_sequences=False, input_shape=(timesteps, feature_dim)),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(X, y, epochs=5, batch_size=32, validation_split=0.1, verbose=1)

model.summary()
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5156 - loss: 1.5686 - val_accuracy: 0.5583 - val_loss: 1.4866
# Epoch 2/5
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5952 - loss: 1.3624 - val_accuracy: 0.5599 - val_loss: 1.4800
# Epoch 3/5
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6024 - loss: 1.3474 - val_accuracy: 0.5623 - val_loss: 1.4483
# Epoch 4/5
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6015 - loss: 1.3324 - val_accuracy: 0.5607 - val_loss: 1.4462
# Epoch 5/5
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6075 - loss: 1.3103 - val_accuracy: 0.5632 - val_loss: 1.4296
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │         1,548 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 204,326 (798.15 KB)
#  Trainable params: 68,108 (266.05 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 136,218 (532.11 KB)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Get predictions for all sequences
y_true = np.argmax(y, axis=1)  # ground truth labels (from one-hot to index)
y_pred = []

for i in range(len(X)):
    seq = np.expand_dims(X[i], axis=0)  # reshape for LSTM (1, timesteps)
    probs = model.predict(seq, verbose=0)
    pred_index = np.argmax(probs)
    y_pred.append(pred_index)

y_pred = np.array(y_pred)

# 2. Compute overall accuracy
acc = accuracy_score(y_true, y_pred)
print(f"LSTM accuracy: {acc*100:.2f}%")

# 3. Classification report (precision, recall, f1)
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_, zero_division=0))

# 4. Confusion matrix
cm = confusion_matrix(y_true, y_pred)

counts = Counter(encoded_actions)
labels = le.inverse_transform(list(counts.keys()))

plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=False, cmap="Blues", xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - Ball Action Prediction")
plt.tight_layout()
plt.show()

# %%
# Pick one test sequence (last one in X for example)
test_seq = np.expand_dims(X[-1], axis=0)  # shape (1, seq_length, feature_dim)

# Predict probabilities
pred_probs = model.predict(test_seq, verbose=0)

# Get predicted class index
pred_index = np.argmax(pred_probs)

# Decode to action label
pred_label = le.inverse_transform([pred_index])[0]

print("\n--- Next Ball Action Prediction ---")
print("Input sequence (last 5 actions):", le.inverse_transform(X[-1]))
print("Predicted next action:", pred_label)
# Out:
# --- Next Ball Action Prediction ---
# Input sequence (last 5 actions): ['HEADER' 'DRIVE' 'PASS' 'DRIVE' 'SHOT']
# Predicted next action: DRIVE
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Random prediction
def random_baseline(num_samples, num_classes):
    return np.random.choice(num_classes, size=num_samples)

# %%
#Weighted random based on frequency
action_counts = Counter(encoded_actions)
total_actions = sum(action_counts.values())
weights = np.array([action_counts[i]/total_actions for i in range(num_classes)])

def weighted_random_baseline(num_samples, weights):
    return np.random.choice(len(weights), size=num_samples, p=weights)

# %%
# Evaluate models
from sklearn.metrics import top_k_accuracy_score

y_true = np.argmax(y, axis=1)

# Random baseline
y_pred_random = random_baseline(len(y_true), num_classes)
print(f"Random baseline accuracy: {accuracy_score(y_true, y_pred_random)*100:.2f}%")

# Weighted random baseline
y_pred_weighted = weighted_random_baseline(len(y_true), weights)
print(f"Weighted random baseline accuracy: {accuracy_score(y_true, y_pred_weighted)*100:.2f}%")

# LSTM model predictions
y_true = np.argmax(y, axis=1)
y_pred_lstm = model.predict(X, verbose=0) # Get probabilities for top-k

acc_top1 = accuracy_score(y_true, np.argmax(y_pred_lstm, axis=1))
print(f"LSTM accuracy (Top-1): {acc_top1*100:.2f}%")

acc_top3 = top_k_accuracy_score(y_true, y_pred_lstm, k=3, labels=np.arange(num_classes))
print(f"LSTM accuracy (Top-3): {acc_top3*100:.2f}%")

from sklearn.metrics import f1_score

f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"F1 Score : {f1 * 100:.2f}%")
# Out:
# Random baseline accuracy: 8.17%
# Weighted random baseline accuracy: 29.35%
# LSTM accuracy (Top-1): 59.98%
# LSTM accuracy (Top-3): 83.28%
# F1 Score : 11.45%

# %%
---------------------------------------------

# %%
# with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/train_labels.zip') as zf:
#     zf.pwd = b's0cc3rn3t'
#     zf.extractall('/content/SoccerNet/SN-BAS-2025/test_labels')
# with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/test_labels') as zf:
#     zf.pwd = b's0cc3rn3t'
#     zf.extractall('/content/SoccerNet/SN-BAS-2025/train_labels')
# with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/valid_labels.zip') as zf:
#     zf.pwd = b's0cc3rn3t'
#     zf.extractall('/content/SoccerNet/SN-BAS-2025/valid_labels')
# with pyzipper.AESZipFile('/content/SoccerNet/SN-BAS-2025/challenge_labels.zip') as zf:
#     zf.pwd = b's0cc3rn3t'
#     zf.extractall('/content/SoccerNet/SN-BAS-2025/challenge_labels')
